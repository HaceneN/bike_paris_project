# %% [markdown]
# # 1- Charger le fichier csv

# %%
import lux 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


QA_data = pd.read_csv("indices_QA/indices_QA_commune_IDF_2017.csv")
QA_data["date"] = pd.to_datetime(QA_data["date"])

# %%
QA_data
# Out:
# /home/fitec/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:345: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
#
# Please report this issue on Github: https://github.com/lux-org/lux/issues
#   return method()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/lux/core/frame.py in _repr_html_(self)
#     569                                 # df_to_display.maintain_recs() # compute the recommendations (TODO: This can be rendered in another thread in the background to populate self._widget)
# --> 570                                 self.maintain_recs()
#     571
#
# ~/anaconda3/lib/python3.8/site-packages/lux/core/frame.py in maintain_recs(self)
#     434                                         rec_df._append_rec(rec_infolist, univariate(rec_df,"nominal"))
# --> 435                                         rec_df._append_rec(rec_infolist, univariate(rec_df,"temporal"))
#     436                                 elif (one_current_vis):
#
# ~/anaconda3/lib/python3.8/site-packages/lux/action/univariate.py in univariate(ldf, data_type_constraint)
#      66         for vis in vlist:
# ---> 67                 vis.score = interestingness(vis,ldf)
#      68         # vlist = vlist.topK(15) # Basic visualizations should not be capped
#
# ~/anaconda3/lib/python3.8/site-packages/lux/interestingness/interestingness.py in interestingness(vis, ldf)
#      68                 if (n_filter == 0):
# ---> 69                         return unevenness(vis, ldf, measure_lst, dimension_lst)
#      70                 elif(n_filter==1):
#
# ~/anaconda3/lib/python3.8/site-packages/lux/interestingness/interestingness.py in unevenness(vis, ldf, measure_lst, dimension_lst)
#     236         v = vis.data[measure_lst[0].attribute]
# --> 237         v = v/v.sum() # normalize by total to get ratio
#     238         C = ldf.cardinality[dimension_lst[0].attribute]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
# ---> 64
#      65         return method(self, other)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     502         # GH17901
# --> 503         right = to_series(right)
#     504
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op, str_rep)
#     196     """
# --> 197     Evaluate a comparison operation `=`, `!=`, `>=`, `>`, `<=`, or `<`.
#     198
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148             #  will handle complex numbers incorrectly, see GH#32047
# --> 149             raise
#     150         result = masked_arith_op(left, right, op)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#      99
# --> 100     if _can_use_numexpr(op, op_str, a, b, "evaluate"):
#     101         is_reversed = op.__name__.strip("_").startswith("r")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _can_use_numexpr(op, op_str, a, b, dtype_check)
#      75         # required min elements (otherwise we are adding overhead)
# ---> 76         if np.prod(a.shape) > _MIN_ELEMENTS:
#      77             # check for dtype compatibility
#
# AttributeError: 'str' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             self.info(buf=buf)
#     733             return buf.getvalue()
# --> 734
#     735         max_rows = get_option("display.max_rows")
#     736         min_rows = get_option("display.min_rows")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980             Whether the generated HTML is for IPython Notebook.
#     981         border : int
# --> 982             A ``border=border`` attribute is included in the opening
#     983             ``<table>`` tag. Default ``pd.options.display.html.border``.
#     984         """
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border)
#      57         self.col_space = {
#      58             column: f"{value}px" if isinstance(value, int) else value
# ---> 59             for column, value in self.fmt.col_space.items()
#      60         }
#      61
#
# AttributeError: 'NoneType' object has no attribute 'items'
#              date  ninsee  no2  o3  pm10
# 0      2017-01-01       0   23  16    43
# 1      2017-01-01      75   23   8    38
# 2      2017-01-01      77   19  17    44
# 3      2017-01-01      78   16  15    32
# 4      2017-01-01      91   14  16    34
# ...           ...     ...  ...  ..   ...
# 476480 2017-12-31   95676    7  36    15
# 476481 2017-12-31   95678    8  35    15
# 476482 2017-12-31   95680    8  33    14
# 476483 2017-12-31   95682    8  35    14
# 476484 2017-12-31   95690    7  38    15
#
# [476485 rows x 5 columns]

# %% [markdown]
# # 2- Afficher les indices QA de Paris 75

# %%
dept_paris = QA_data["ninsee"] == 75
paris_QA = QA_data[dept_paris]

# %%
#paris_QA.head()
QA_data.shape
# Out:
# (476485, 5)

# %%
date  = np.array(paris_QA["date"])

NO2_rate = np.array(paris_QA["no2"])
plt.plot(list(range(1,366)), NO2_rate)
plt.xlabel("date")
plt.ylabel("Taux No2")
plt.axis([1, 365, 0, 100])
# Out:
# (1.0, 365.0, 0.0, 100.0)

# %% [markdown]
# # 3- Afficher les indices QA des arrondissement de paris
# ## 1- 1er arrondissement

# %%
arronds_paris = QA_data[QA_data["ninsee"] == 75101]
no2_rate_1er = arronds_paris["no2"]
arronds_paris.head
# Out:
# <bound method LuxDataFrame.head of >

# %%
x_axis = list(range(1,365))
No2_rate_1er = np.array(no2_rate_1er)

plt.plot(x_axis, No2_rate_1er)
plt.xlabel("date")
plt.ylabel("Taux No2")
plt.xlim([100, 110])
#plt.axis([1, 366, 0, 100])
# Out:
# (100.0, 110.0)

# %% [markdown]
# ** Aficher les stats d'un seul mois

# %%
No2_rate_1er
# Out:
# array([20, 32, 35, 34, 38, 35, 31, 36, 28, 37, 28, 33, 29, 30, 34, 32, 31,
#        33, 41, 34, 46, 46, 37, 39, 26, 36, 51, 40, 34, 32, 39, 27, 35, 28,
#        43, 38, 31, 40, 33, 30, 30, 24, 30, 22, 32, 46, 53, 46, 50, 48, 32,
#        27, 26, 20, 44, 49, 23, 21, 29, 30, 41, 44, 34, 14, 35, 47, 28, 31,
#        42, 49, 45, 26, 36, 45, 55, 28, 17, 19, 24, 41, 37, 26, 35, 38, 45,
#        45, 53, 54, 51, 43, 25, 33, 51, 46, 24, 28, 38, 46, 57, 26, 34, 36,
#        24, 33, 18, 14, 15, 35, 28, 41, 47, 34, 26, 44, 23, 33, 33, 44, 41,
#        18, 15, 27, 33, 45, 22, 29, 17, 17, 27, 44, 37, 37, 26, 16, 51, 44,
#        40, 19, 21, 28, 29, 51, 24, 28, 20, 21, 24, 26, 44, 19, 19, 33, 44,
#        15, 36, 30, 14, 22, 32, 22, 42, 50, 14, 20, 44, 37, 15, 26, 18, 35,
#        52, 60, 59, 15, 16, 17, 15, 35, 19, 18, 25, 17, 17, 23, 36, 33, 49,
#        34, 18, 26, 23, 27, 20, 29, 11, 16, 14, 15, 38, 33, 15, 24, 20, 13,
#        16, 18, 32, 23, 18, 14, 14, 26, 35, 39, 13, 18, 16, 17, 26, 28, 21,
#        23, 19, 16, 44, 40, 25, 39, 17, 20, 18, 23, 26, 21, 26, 30, 39, 49,
#        39, 51, 46, 25, 25, 32, 42, 37, 31, 18, 19, 22, 19, 21, 13, 16, 26,
#        25, 25, 29, 33, 40, 36, 33, 44, 54, 46, 51, 39, 35, 46, 39, 33, 25,
#        19, 21, 36, 37, 31, 33, 31, 19, 35, 26, 36, 36, 49, 45, 40, 40, 47,
#        44, 34, 33, 16, 16, 28, 26, 34, 42, 35, 26, 23, 38, 45, 36, 46, 33,
#        25, 33, 38, 47, 41, 34, 31, 23, 28, 28, 37, 38, 45, 37, 40, 37, 29,
#        29, 39, 37, 37, 30, 23, 26, 38, 31, 36, 34, 30, 27, 39, 52, 33, 25,
#        28, 26, 27, 24, 35, 25, 26, 29, 33, 25, 36, 38, 32, 29, 35, 33, 18,
#        15, 22, 23, 32, 26, 16, 12])

# %%
import datetime
vect_date = pd.to_datetime(QA_data["date"])

mask_jan = (QA_data["date"] <= '2017-01-31')
mask_feb = (QA_data["date"] >= '2017-02-01')  & (QA_data["date"] <= '2017-02-28')
mask_mar = (QA_data["date"] >= '2017-03-01')  & (QA_data["date"] <= '2017-03-31')
mask_apr = (QA_data["date"] >= '2017-04-01')  & (QA_data["date"] <= '2017-04-30')
mask_may = (QA_data["date"] >= '2017-05-01')  & (QA_data["date"] <= '2017-05-31')
mask_jun = (QA_data["date"] >= '2017-06-01')  & (QA_data["date"] <= '2017-06-30')

jan = arronds_paris[mask_jan]
feb = arronds_paris[mask_feb]
mar = arronds_paris[mask_mar]
apr = arronds_paris[mask_apr]
may = arronds_paris[mask_may]
jun = arronds_paris[mask_jun]

jan = jan.sort_values(by='date')
feb = feb.sort_values(by='date')
mar = mar.sort_values(by='date')
apr = apr.sort_values(by='date')
may = may.sort_values(by='date')
jun = jun.sort_values(by='date')
# Out:
# <ipython-input-46-c983c4976b44>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jan = arronds_paris[mask_jan]
# <ipython-input-46-c983c4976b44>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   feb = arronds_paris[mask_feb]
# <ipython-input-46-c983c4976b44>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mar = arronds_paris[mask_mar]
# <ipython-input-46-c983c4976b44>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   apr = arronds_paris[mask_apr]
# <ipython-input-46-c983c4976b44>:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   may = arronds_paris[mask_may]
# <ipython-input-46-c983c4976b44>:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jun = arronds_paris[mask_jun]

# %%
x_axis1 = list(range(1,32))
plt.plot(x_axis1, (jan["no2"]))
plt.subplot(231)

x_axis2 = list(range(1,29))
plt.plot(x_axis2, (feb["no2"]))
plt.subplot(232)

x_axis3 = list(range(1,32))
plt.plot(x_axis3, (mar["no2"]))
plt.subplot(233)

x_axis4 = list(range(1,31))
plt.plot(x_axis4, (apr["no2"]))
plt.subplot(234)

x_axis5 = list(range(1,32))
plt.plot(x_axis5, (may["no2"]))
plt.subplot(235)

x_axis6 = list(range(1,31))
plt.plot(x_axis6, (jun["no2"]))
plt.subplot(236)

#plt.xlabel("date")
#plt.ylabel("Taux No2")

# %% [markdown]
# # 4- Comparer la pollution des depts ïle-de-France

# %%
data_75 = QA_data [QA_data ["ninsee"] == 75]
data_77 = QA_data [QA_data ["ninsee"] == 77]
data_78 = QA_data [QA_data ["ninsee"] == 78]
data_91 = QA_data [QA_data ["ninsee"] == 91]
data_92 = QA_data [QA_data ["ninsee"] == 92]
data_93 = QA_data [QA_data ["ninsee"] == 93]
data_94 = QA_data [QA_data ["ninsee"] == 94]

m75 = data_75["no2"].mean()
m77 = data_77["no2"].mean()
m78 = data_78["no2"].mean()
m91 = data_91["no2"].mean()
m92 = data_92["no2"].mean()
m93 = data_93["no2"].mean()
m94 = data_94["no2"].mean()

[m75, m77, m78, m91, m92, m93, m94]
# Out:
# [36.11232876712329,
#  30.123287671232877,
#  27.378082191780823,
#  28.649315068493152,
#  33.57260273972603,
#  35.93150684931507,
#  33.66027397260274]

# %%
plt.bar(["75", "77", "78", "91","92","93","94"], [m75, m77, m78, m91, m92, m93, m94], alpha = 0.5, color = "b")
plt.ylabel("NO2 rate")
plt.xlabel("Departements")
# Out:
# Text(0.5, 0, 'Departements')

# %%
pip install lux-api
# Out:
# Collecting lux-api
#   Downloading lux_api-0.2.0-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 82 kB/s eta 0:00:01
# Collecting lux-widget
#   Downloading lux_widget-0.1.0-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 114 kB/s eta 0:00:01
# Requirement already satisfied: pytest>=5.3.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-api) (5.4.3)
# Requirement already satisfied: scipy>=1.3.3 in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-api) (1.5.0)
# Requirement already satisfied: altair>=4.0.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-api) (4.1.0)
# Collecting sphinx-rtd-theme>=0.4.3
#   Downloading sphinx_rtd_theme-0.5.0-py2.py3-none-any.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 134 kB/s eta 0:00:01
# Requirement already satisfied: Sphinx>=3.0.2 in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-api) (3.1.2)
# Requirement already satisfied: scikit-learn>=0.22 in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-api) (0.23.1)
# Collecting vega-datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 108 kB/s eta 0:00:01
# Collecting pytest-cov>=2.8.1
#   Downloading pytest_cov-2.10.1-py2.py3-none-any.whl (19 kB)
# Collecting pandas>=1.1.0
#   Downloading pandas-1.1.4-cp38-cp38-manylinux1_x86_64.whl (9.3 MB)
#      |████████████████████████████████| 9.3 MB 171 kB/s eta 0:00:01
# Requirement already satisfied: jupyter in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-api) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-widget->lux-api) (7.5.1)
# Requirement already satisfied: notebook>=4.0.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from lux-widget->lux-api) (6.0.3)
# Requirement already satisfied: py>=1.5.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from pytest>=5.3.1->lux-api) (1.9.0)
# Requirement already satisfied: packaging in /home/fitec/anaconda3/lib/python3.8/site-packages (from pytest>=5.3.1->lux-api) (20.4)
# Requirement already satisfied: attrs>=17.4.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from pytest>=5.3.1->lux-api) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from pytest>=5.3.1->lux-api) (8.4.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /home/fitec/anaconda3/lib/python3.8/site-packages (from pytest>=5.3.1->lux-api) (0.13.1)
# Requirement already satisfied: wcwidth in /home/fitec/anaconda3/lib/python3.8/site-packages (from pytest>=5.3.1->lux-api) (0.2.5)
# Requirement already satisfied: numpy>=1.14.5 in /home/fitec/anaconda3/lib/python3.8/site-packages (from scipy>=1.3.3->lux-api) (1.18.5)
# Requirement already satisfied: jinja2 in /home/fitec/anaconda3/lib/python3.8/site-packages (from altair>=4.0.0->lux-api) (2.11.2)
# Requirement already satisfied: jsonschema in /home/fitec/anaconda3/lib/python3.8/site-packages (from altair>=4.0.0->lux-api) (3.2.0)
# Requirement already satisfied: toolz in /home/fitec/anaconda3/lib/python3.8/site-packages (from altair>=4.0.0->lux-api) (0.10.0)
# Requirement already satisfied: entrypoints in /home/fitec/anaconda3/lib/python3.8/site-packages (from altair>=4.0.0->lux-api) (0.3)
# Requirement already satisfied: babel>=1.3 in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (2.8.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (2.0.0)
# Requirement already satisfied: requests>=2.5.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (2.24.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (1.0.3)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (0.7.12)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (1.1.4)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (1.0.2)
# Requirement already satisfied: docutils>=0.12 in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (0.16)
# Requirement already satisfied: imagesize in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (1.2.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (1.0.1)
# Requirement already satisfied: setuptools in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (49.2.0.post20200714)
# Requirement already satisfied: Pygments>=2.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from Sphinx>=3.0.2->lux-api) (2.6.1)
# Requirement already satisfied: joblib>=0.11 in /home/fitec/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22->lux-api) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22->lux-api) (2.1.0)
# Collecting coverage>=4.4
#   Downloading coverage-5.3-cp38-cp38-manylinux1_x86_64.whl (230 kB)
#      |████████████████████████████████| 230 kB 72 kB/s eta 0:00:011
# Requirement already satisfied: pytz>=2017.2 in /home/fitec/anaconda3/lib/python3.8/site-packages (from pandas>=1.1.0->lux-api) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/fitec/anaconda3/lib/python3.8/site-packages (from pandas>=1.1.0->lux-api) (2.8.1)
# Requirement already satisfied: nbconvert in /home/fitec/anaconda3/lib/python3.8/site-packages (from jupyter->lux-api) (5.6.1)
# Requirement already satisfied: ipykernel in /home/fitec/anaconda3/lib/python3.8/site-packages (from jupyter->lux-api) (5.3.2)
# Requirement already satisfied: jupyter-console in /home/fitec/anaconda3/lib/python3.8/site-packages (from jupyter->lux-api) (6.1.0)
# Requirement already satisfied: qtconsole in /home/fitec/anaconda3/lib/python3.8/site-packages (from jupyter->lux-api) (4.7.5)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->lux-widget->lux-api) (7.16.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->lux-widget->lux-api) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->lux-widget->lux-api) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->lux-widget->lux-api) (5.0.7)
# Requirement already satisfied: Send2Trash in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (1.5.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (6.1.6)
# Requirement already satisfied: prometheus-client in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (0.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (4.6.3)
# Requirement already satisfied: tornado>=5.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (6.0.4)
# Requirement already satisfied: ipython-genutils in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /home/fitec/anaconda3/lib/python3.8/site-packages (from notebook>=4.0.0->lux-widget->lux-api) (19.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/fitec/anaconda3/lib/python3.8/site-packages (from packaging->pytest>=5.3.1->lux-api) (2.4.7)
# Requirement already satisfied: six in /home/fitec/anaconda3/lib/python3.8/site-packages (from packaging->pytest>=5.3.1->lux-api) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/fitec/anaconda3/lib/python3.8/site-packages (from jinja2->altair>=4.0.0->lux-api) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from jsonschema->altair>=4.0.0->lux-api) (0.16.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from requests>=2.5.0->Sphinx>=3.0.2->lux-api) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /home/fitec/anaconda3/lib/python3.8/site-packages (from requests>=2.5.0->Sphinx>=3.0.2->lux-api) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/fitec/anaconda3/lib/python3.8/site-packages (from requests>=2.5.0->Sphinx>=3.0.2->lux-api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fitec/anaconda3/lib/python3.8/site-packages (from requests>=2.5.0->Sphinx>=3.0.2->lux-api) (2020.6.20)
# Requirement already satisfied: bleach in /home/fitec/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->lux-api) (3.1.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->lux-api) (1.4.2)
# Requirement already satisfied: testpath in /home/fitec/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->lux-api) (0.4.4)
# Requirement already satisfied: defusedxml in /home/fitec/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->lux-api) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/fitec/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->lux-api) (0.8.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from jupyter-console->jupyter->lux-api) (3.0.5)
# Requirement already satisfied: qtpy in /home/fitec/anaconda3/lib/python3.8/site-packages (from qtconsole->jupyter->lux-api) (1.9.0)
# Requirement already satisfied: backcall in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->lux-widget->lux-api) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->lux-widget->lux-api) (4.8.0)
# Requirement already satisfied: decorator in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->lux-widget->lux-api) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->lux-widget->lux-api) (0.17.1)
# Requirement already satisfied: pickleshare in /home/fitec/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->lux-widget->lux-api) (0.7.5)
# Requirement already satisfied: webencodings in /home/fitec/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->lux-api) (0.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/fitec/anaconda3/lib/python3.8/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->lux-widget->lux-api) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/fitec/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->lux-widget->lux-api) (0.7.0)
# Installing collected packages: lux-widget, sphinx-rtd-theme, pandas, vega-datasets, coverage, pytest-cov, lux-api
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
# Successfully installed coverage-5.3 lux-api-0.2.0 lux-widget-0.1.0 pandas-1.1.4 pytest-cov-2.10.1 sphinx-rtd-theme-0.5.0 vega-datasets-0.9.0
# Note: you may need to restart the kernel to use updated packages.
